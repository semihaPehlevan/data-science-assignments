# %%
ad = "Semiha"
soyad = "Pehlevan"
yas = 21
universite = "Sakarya Üniversitesi"
bolum = "Yönetim Bilişim Sistemleri"
hedef = "Yapay zeka ve veri bilimi alanında uzmanlaşmak"

# %%
print("Merhaba, ben", ad, soyad + ".")
print(yas, "yaşındayım ve", universite, "öğrencisiyim.")
print("Bölümüm:", bolum + ".")
print("Gelecekte", hedef + " istiyorum.")
# Out:
# Merhaba, ben Semiha Pehlevan.
# 21 yaşındayım ve Sakarya Üniversitesi öğrencisiyim.
# Bölümüm: Yönetim Bilişim Sistemleri.
# Gelecekte Yapay zeka ve veri bilimi alanında uzmanlaşmak istiyorum.
